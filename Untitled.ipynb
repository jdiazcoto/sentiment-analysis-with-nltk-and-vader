# %% [markdown]
# ## Necessary imports:
#
#     *https://www.nltk.org/
#     *https://pandas.pydata.org/
#
#
# ## Good description of what is being done:
# https://towardsdatascience.com/sentimental-analysis-using-vader-a3415fef7664

# %%
import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jdiaz/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## FIRST TRY

# %%
## Import the whole data set, and remove newline characters
##with open('datasetSentences.txt') as f:
  ##  lines = f.read()
##df_new = pd.DataFrame(lines)
##df_new.head()
#Remove tabs reading line by line
#new_clean_of_text = []
#for line in lines:
#    line = line.strip('\t')
#    new_clean_of_text.append(line)

# %% [markdown]
# # SECOND TRY

# %%
df = pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    sentence_index                                           sentence
# 0               1  The Rock is destined to be the 21st Century 's...
# 1               2  The gorgeously elaborate continuation of `` Th...
# 2               3                     Effective but too-tepid biopic
# 3               4  If you sometimes like to go to the movies to h...
# 4               5  Emerges as something rare , an issue movie tha...

# %%
df_sentences = pd.DataFrame(df['sentence'])
    df['score'] = df['review'].apply(lambda review:sid.polarity_scores(str(review)))
# Out:
#                                             sentence
# 0  The Rock is destined to be the 21st Century 's...
# 1  The gorgeously elaborate continuation of `` Th...
# 2                     Effective but too-tepid biopic
# 3  If you sometimes like to go to the movies to h...
# 4  Emerges as something rare , an issue movie tha...

# %%
polarbear = []
sentence_list = []
for index, row in df_sentences.iterrows():
    a = row['sentence']
    sentence_list.append(a)
    #polarities.append(sid.polarity_scores(a))

# %%
type(sentence_list)
# Out:
# list

# %%
sentence_list_str = []
for sentence in sentence_list:
    sentence_list_str.append(str(sentence))
    

for sent in sentence_list_str:
    a = sent
    b = sid.polarity_scores(a)
    polarbear.append(b)

# %%
print(a)
# Out:
# The Rock is destined to be the 21st Century 's new `` Conan '' and that he 's going to make a splash even greater than Arnold Schwarzenegger , Jean-Claud Van Damme or Steven Segal .

# %%
print(polarbear)
# Out:
# [{'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.3612}, {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.8069}, {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.2617}, {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.8271}, {'neg': 0.079, 'neu': 0.676, 'pos': 0.244, 'compound': 0.6592}, {'neg': 0.078, 'neu': 0.684, 'pos': 0.238, 'compound': 0.5994}, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4215}, {'neg': 0.265, 'neu': 0.623, 'pos': 0.113, 'compound': -0.5994}, {'neg': 0.147, 'neu': 0.637, 'pos': 0.216, 'compound': 0.1852}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4939}, {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4588}, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6115}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.2944}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.6249}, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.5859}, {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.6249}, {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.3818}, {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9058}, {'neg': 0.348, 'neu': 0.652, 'pos': 0.0, 'compound': -0.7506}, {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5719}, {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.4588}, {'neg': 0.0, 'neu': 0.639, 'pos': 0.361, 'compound': 0.5256}, {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.8658}, {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4215}, {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.6705}, {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.8316}, {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.1027}, {'neg': 0.192, 'neu': 0.698, 'pos': 0.11, 'compound': -0.1027}, {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}, {'neg': 0.175, 'neu': 0.656, 'pos': 0.169, 'compound': -0.0516}, {'neg': 0.113, 'neu': 0.659, 'pos': 0.228, 'compound': 0.6361}, {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}, {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}, {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.2023}, {'neg': 0.049, 'neu': 0.711, 'pos': 0.24, 'compound': 0.8625}, {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.6597}, {'neg': 0.096, 'neu': 0.75, 'pos': 0.154, 'compound': 0.34}, {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}, {'neg': 0.0, 'neu': 0.531, 'pos': 0.469, 'compound': 0.8658}, {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.7906}, {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'compound': 0.3612}, {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.5859}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}, {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.7906}, {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.34}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5719}, {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.6705}, {'neg': 0.104, 'neu': 0.736, 'pos': 0.16, 'compound': 0.3182}, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.6124}, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5859}, {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}, {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.631}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.5859}, {'neg': 0.073, 'neu': 0.749, 'pos': 0.178, 'compound': 0.582}, {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.5106}, {'neg': 0.165,  ...
